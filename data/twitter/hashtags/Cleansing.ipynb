# %%
import pandas as pd
import numpy as np

# %%
threat = pd.read_csv("../hashtags/threat.csv")

# %%
threat.head()
# Out:
#              Timestamp                                         tweet_text  \
# 0  2020-09-12 09:08:39  b"https://t.co/y7CRBRgU28  @PMCPune @SmartPune...
# 1  2020-09-12 07:34:56  b'Boris #Johnson: #EU a #threat to #integrity ...
# 2  2020-09-12 07:26:45  b'BIPSS realizes that to understand the threat...
# 3  2020-09-12 06:28:35  b'*FLASH*  03 AK47, 02 M16 Rifles, 02 pistols ...
# 4  2020-09-12 05:44:55  b'The future has arrived! These explosive #wil...
#
#            Username              User_loc  \
# 0  b'KapilSawakare'       b'Pune, India.'
# 1          b'CGH54'          b'UK- Wales'
# 2          b'bipss'  b'Dhaka, Bangladesh'
# 3    b'JKCHANNEL10'       b'Jammu, India'
# 4     b'Gender_Env'  b'Bangkok, Thailand'
#
#                                         All_hashtags  UserID_verified  \
# 0           ['hospital', 'bed', 'Threat', 'Punekar']            False
# 1     ['Johnson', 'EU', 'threat', 'integrity', 'UK']            False
# ...

# %%
threat=threat.drop(columns=['Username','UserID_verified','followers_count'])

# %%
threat['User_loc'] = threat.User_loc.str.replace('b,?' , '')
threat['tweet_text'] = threat.tweet_text.str.replace('b,?' , '')

# %%
threat
# Out:
#                Timestamp                                         tweet_text  \
# 0    2020-09-12 09:08:39  "https://t.co/y7CRBRgU28  @PMCPune @SmartPune ...
# 1    2020-09-12 07:34:56  'Boris #Johnson: #EU a #threat to #integrity o...
# 2    2020-09-12 07:26:45  'BIPSS realizes that to understand the threat ...
# 3    2020-09-12 06:28:35  '*FLASH*  03 AK47, 02 M16 Rifles, 02 pistols &...
# 4    2020-09-12 05:44:55  'The future has arrived! These explosive #wild...
# ..                   ...                                                ...
# 495  2020-09-04 06:16:17  '@DavidBCollum Sounds like a #threat to the #P...
# 496  2020-09-04 06:13:55  '#Catholic #Bishops #Tell #Catholics to #Vote ...
# 497  2020-09-04 06:08:52  'Trump\'s Profa killers and terrorists which a...
# 498  2020-09-04 06:06:38  'Never ending Harassment to our President Dona...
# 499  2020-09-04 04:24:59  '#UPPolice #StopTheKillings This is igger #thr...
#
# ...
